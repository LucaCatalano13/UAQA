# %% [markdown]
# # Colab setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
! cp /content/drive/MyDrive/full_day_data_fill_file_train.pt /content/

# %%
! cp /content/drive/MyDrive/full_day_data_fill_file_test.pt /content/

# %%
# !unzip -q adsp_milan_dataset.zip -d /content

# %%
# !unzip -q milan_crop_legend.zip -d /content

# %%
# !unzip -q milan_crop_23.zip -d /content

# %%
# !unzip -q /content/drive/MyDrive/weak_labels_merge.zip -d /content

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/LucaCatalano13/UAQA.git
# Out:
# Cloning into 'UAQA'...
# remote: Enumerating objects: 1282, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 1282 (delta 100), reused 107 (delta 50), pack-reused 1121
# Receiving objects: 100% (1282/1282), 68.43 MiB | 23.87 MiB/s, done.
# Resolving deltas: 100% (801/801), done.

# %%
# !pip install -r "/content/UAQA/requirements.txt"
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 46.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 777.7/777.7 kB 52.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 79.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 35.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 105.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.1/973.1 kB 73.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 94.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 519.8 kB/s eta 0:00:00
# ...

# %% [markdown]
# # Reload Github - NOT RUN FIRST TIME

# %%
! rm -r /content/UAQA

# %%
# !git clone https://github.com/LucaCatalano13/UAQA.git
# Out:
# Cloning into 'UAQA'...
# remote: Enumerating objects: 1285, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 1285 (delta 102), reused 108 (delta 52), pack-reused 1121
# Receiving objects: 100% (1285/1285), 68.43 MiB | 23.38 MiB/s, done.
# Resolving deltas: 100% (803/803), done.

# %% [markdown]
# #   Run train.py

# %%
# !python UAQA/train.py --input_train_path "full_day_data_fill_file_train.pt" \
                      --input_test_path "full_day_data_fill_file_test.pt" \
                      --wandb_project "UAQA" \
                      --encoder_depth 5 \
                      --decoder_depth 5 \
                      --num_epochs 40 \
                      --wandb_name "UAQA-run-40-epoch-128bs-5depth"
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: wandb version 0.16.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in ./wandb/run-20240104_141730-1ru1p6f1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run UAQA-run-40-epoch-128bs-5depth
# wandb: ⭐️ View project at https://wandb.ai/uaqa/UAQA
# wandb: 🚀 View run at https://wandb.ai/uaqa/UAQA/runs/1ru1p6f1
# ...

# %% [markdown]
# #   Run forecasting_train.py

# %%
# !python UAQA/forecasting_train.py --input_train_path "full_day_data_fill_file_train.pt" \
                      --input_test_path "full_day_data_fill_file_test.pt" \
                      --golden_stations_test_path "/content/weak_labels_merge/stations_data_test.csv" \
                      --stations_test_path "/content/weak_labels_merge/weak_labels_test" \
                      --stations_path "/content/weak_labels_merge/weak_labels_train" \
                      --golden_stations_path "/content/weak_labels_merge/stations_data_train.csv" \
                      --stations_legend_path "/content/weak_labels_merge/channels.json" \
                      --golden_stations_legend_path "/content/weak_labels_merge/qaria_stazione.csv" \
                      --model_presto_path "/content/_epoch(39).ckpt"\
                      --wandb_project "UAQA" \
                      --encoder_depth 4 \
                      --decoder_depth 4 \
                      --num_epochs 40 \
                      --wandb_name "UAQA-forecasting-run-40-epoch-128bs-4depth-3hidden_layer_MLP"
# Out:
# Loading Train Stations
# Loaded Train Stations
# Loading Test Stations
# Loaded Test Stations
# End dataset loading
# Train Dataloader loading
# Val Dataloader loading
# Test Dataloader loading
# Loading Encoder
# wandb: Currently logged in as: luca-catalano (uaqa). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.16.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in ./wandb/run-20240108_112439-gj04wbcw
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run UAQA-forecasting-run-40-epoch-128bs-4depth-3hidden_layer_MLP
# wandb: ⭐️ View project at https://wandb.ai/uaqa/UAQA
# wandb: 🚀 View run at https://wandb.ai/uaqa/UAQA/runs/gj04wbcw
# ...
